# %% [markdown]
# ## map to wikidata (chemicals)

# %%
from wikidataintegrator import wdi_helpers
import pandas as pd
df = pd.read_csv('fullSeedData-2016-06-16_UNII.csv', index_col=0, low_memory=False)

# %%
# no mixtures
df = df.query("substanceClass == 'chemical'")

# %%
# get all inchikeys in wikidata
inchi_wdid = wdi_helpers.id_mapper("P235")
wdid_inchi = {v:k for k,v in inchi_wdid.items()}
print("{} inchikeys in wikidata".format(len(inchi_wdid)))
# Out:
# 151548 inchikeys in wikidata

# %%
# dict of CAS id to wikidata QID
cas_wdid = wdi_helpers.id_mapper("P231")
print("{} cas numbers in wikidata".format(len(cas_wdid)))
# Out:
# 70755 cas numbers in wikidata

# %%
df['qid_cas'] = df.CAS_primary.map(lambda x:cas_wdid.get(x, None))
df[['CAS_primary', 'qid_cas']].count()
# Out:
# CAS_primary    54190
# qid_cas        52632
# dtype: int64

# %%
# dict of UNII id to wikidata QID
unii_wdid = wdi_helpers.id_mapper("P652")
print("{} UNII in wikidata".format(len(unii_wdid)))
# Out:
# 58967 UNII in wikidata

# %%
df['qid_unii'] = df.UNII.map(lambda x:unii_wdid.get(x, None))
df[['CAS_primary', 'qid_cas', 'qid_unii']].count()
# Out:
# CAS_primary    54190
# qid_cas        52632
# qid_unii       52627
# dtype: int64

# %%
# check agreement of cas and unii, and add inchikey
(df.qid_cas == df.qid_unii).value_counts()
# Out:
# True     52031
# False     2400
# dtype: int64

# %%
df['inchikey_from_wd'] = df[df.qid_cas == df.qid_unii].qid_cas.map(lambda x:wdid_inchi.get(x, None))
df[['CAS', 'UNII', 'qid_cas', 'qid_unii', 'inchikey_from_wd', 'INCHIKEY_from_unii']].count()
# Out:
# CAS                   54431
# UNII                  54431
# qid_cas               52632
# qid_unii              52627
# inchikey_from_wd      51956
# INCHIKEY_from_unii    44673
# dtype: int64

# %%
## Validate inchikeys coming from wikidata with inchikey coming from the UNII mapping
# this is field INCHIKEY_from_unii, which comes from https://fdasis.nlm.nih.gov/srs/download/srs/UNII_Data.zip
agree = df[df.INCHIKEY_from_unii.notnull() & df.inchikey_from_wd.notnull() & (df.INCHIKEY_from_unii == df.inchikey_from_wd)]
disagree = df[df.INCHIKEY_from_unii.notnull() & df.inchikey_from_wd.notnull() & (df.INCHIKEY_from_unii != df.inchikey_from_wd)]
print("number of drugs with exact same inchikey: {}".format(len(agree)))
print("number of drugs with different inchikey (not counting missing): {}".format(len(disagree)))
# Out:
# number of drugs with exact same inchikey: 42304
# number of drugs with different inchikey (not counting missing): 825

# %%
## Don't use ones with disagreements
# keep if found in either wikidata or unii
df['inchikey'] = None
df.inchikey.fillna(df.inchikey_from_wd, inplace=True)
df.inchikey.fillna(df.INCHIKEY_from_unii, inplace=True)
df.loc[df.INCHIKEY_from_unii.notnull() & df.inchikey_from_wd.notnull() & (df.INCHIKEY_from_unii != df.inchikey_from_wd), 'inchikey'] = None
#df[['INCHIKEY_from_unii', 'inchikey_from_wd', 'inchikey']]

# %%
## there are some dupes
vc = df.inchikey.value_counts()
dupes = df[df.inchikey.isin(vc.index[vc > 1])].sort_values("inchikey")
print(len(dupes))
dupes[['UNII', 'CAS', 'INCHIKEY_from_unii', 'inchikey_from_wd', 'inchikey']]
# Out:
# 12
#              UNII          CAS           INCHIKEY_from_unii  \
# 17465  TLN93NUR7S   74635-27-1  BAZSXBOAXJLRNH-UHFFFAOYSA-N
# 51251  OI55X42ZZH   70565-74-1  BAZSXBOAXJLRNH-UHFFFAOYSA-N
# 15202  EBV7H5W26H     595-40-4  GCHPUFAZSONQIV-YFKPBYRVSA-N
# 23949  JUL973T11C     595-39-1                          NaN
# 13416  G56VK1HF36   92623-85-3                          NaN
# 15238  ES1O38J3C4   96847-55-1  GJJFMKBJSRMPLA-HIFRSBDPSA-N
# 23166  1FU18G2315   29804-22-6                          NaN
# 55000  E5FWS893X3   54910-52-0  HFOFYNMWYRXIBP-MOPGFXCFSA-N
# 5462   24QAP1VCUX    5655-61-8  KGEKLUUHTZCSIP-HOSYDEDBSA-N
# 48139  213431586X      76-49-3                          NaN
# 14152  9678LTP737  105015-53-0  WNVCMFHPRIBNCW-HTQZYQBOSA-N
# 31238  W5YC1G1F5D  147254-32-8                          NaN
#
#                   inchikey_from_wd                     inchikey
# 17465                          NaN  BAZSXBOAXJLRNH-UHFFFAOYSA-N
# 51251                          NaN  BAZSXBOAXJLRNH-UHFFFAOYSA-N
# 15202                          NaN  GCHPUFAZSONQIV-YFKPBYRVSA-N
# 23949  GCHPUFAZSONQIV-YFKPBYRVSA-N  GCHPUFAZSONQIV-YFKPBYRVSA-N
# 13416  GJJFMKBJSRMPLA-HIFRSBDPSA-N  GJJFMKBJSRMPLA-HIFRSBDPSA-N
# 15238                          NaN  GJJFMKBJSRMPLA-HIFRSBDPSA-N
# 23166  HFOFYNMWYRXIBP-MOPGFXCFSA-N  HFOFYNMWYRXIBP-MOPGFXCFSA-N
# 55000                          NaN  HFOFYNMWYRXIBP-MOPGFXCFSA-N
# 5462                           NaN  KGEKLUUHTZCSIP-HOSYDEDBSA-N
# 48139  KGEKLUUHTZCSIP-HOSYDEDBSA-N  KGEKLUUHTZCSIP-HOSYDEDBSA-N
# 14152                          NaN  WNVCMFHPRIBNCW-HTQZYQBOSA-N
# 31238  WNVCMFHPRIBNCW-HTQZYQBOSA-N  WNVCMFHPRIBNCW-HTQZYQBOSA-N

# %%
# some things we miss:
missing_or_wrong = df[df.inchikey.isnull()]
missing_or_wrong.to_csv("missing_or_wrong.csv")
len(missing_or_wrong)
# Out:
# 1768

# %%
df.to_csv("fullSeedData-2016-06-16_UNII_wikidata.csv.gz", compression='gzip')

# %%
## Summary (chemicals)
print("{} out of {} mapped to inchikey".format(df.inchikey.notnull().sum(), len(df)))
# Out:
# 52663 out of 54431 mapped to inchikey

# %%
df
df[df.columns[df.count()>200]].head(20)
# Out:
#                         CAS   CAS_primary             CFR  \
# 0                66537-39-1    66537-39-1             NaN
# 1                12068-46-1    12068-46-1             NaN
# 2     51599-37-2|43064-17-1    51599-37-2             NaN
# 3                  504-64-3      504-64-3             NaN
# 4                 6362-80-7     6362-80-7             NaN
# 5               446255-20-5   446255-20-5             NaN
# 6                14536-00-6    14536-00-6             NaN
# 7              1079400-07-9  1079400-07-9             NaN
# 8                 7020-55-5     7020-55-5             NaN
# 9                19902-91-1    19902-91-1             NaN
# 10                 122-63-4      122-63-4  21 CFR 172.515
# 11               56271-94-4    56271-94-4             NaN
# 12              607837-17-2   607837-17-2             NaN
# 13  736128-16-8|956499-66-4   736128-16-8             NaN
# 14                  53-18-9       53-18-9             NaN
# 15                 622-39-9      622-39-9             NaN
# 16                6864-37-5     6864-37-5             NaN
# 17              125109-85-5   125109-85-5             NaN
# 18               34408-14-5    34408-14-5             NaN
# 19               25394-63-2    25394-63-2             NaN
#
#    CODEX ALIMENTARIUS (GSFA) DEA NO. DRUG BANK ECHA (EC/EINECS)  \
# 0                        NaN     NaN       NaN              NaN
# 1                        NaN     NaN       NaN        235-099-1
# 2                        NaN     NaN       NaN              NaN
# 3                        NaN     NaN       NaN              NaN
# 4                        NaN     NaN       NaN        228-846-8
# 5                        NaN     NaN       NaN              NaN
# 6                        NaN     NaN       NaN        238-569-4
# 7                        NaN     NaN       NaN              NaN
# 8                        NaN     NaN   DB00771              NaN
# 9                        NaN     NaN       NaN              NaN
# 10                       NaN     NaN       NaN        204-559-3
# 11                       NaN     NaN       NaN        260-086-2
# 12                       NaN     NaN       NaN              NaN
# 13                       NaN     NaN       NaN              NaN
# 14                       NaN     NaN       NaN        200-165-0
# 15                       NaN     NaN       NaN        210-732-4
# 16                       NaN     NaN       NaN        229-962-1
# 17                       NaN     NaN       NaN              NaN
# 18                       NaN     NaN       NaN              NaN
# 19                       NaN     NaN       NaN              NaN
#
#    EMA ASSESSMENT REPORTS EPA PESTICIDE CODE        EVMPD  \
# 0                     NaN                NaN          NaN
# 1                     NaN                NaN          NaN
# 2                     NaN                NaN          NaN
# 3                     NaN                NaN          NaN
# 4                     NaN                NaN          NaN
# 5                     NaN                NaN          NaN
# 6                     NaN                NaN          NaN
# 7                     NaN                NaN          NaN
# 8                     NaN                NaN          NaN
# 9                     NaN                NaN          NaN
# 10                    NaN                NaN          NaN
# 11                    NaN                NaN          NaN
# 12                    NaN                NaN          NaN
# 13                    NaN                NaN          NaN
# 14                    NaN                NaN  SUB05826MIG
# 15                    NaN                NaN          NaN
# 16                    NaN                NaN          NaN
# 17                    NaN                NaN          NaN
# 18                    NaN                NaN          NaN
# 19                    NaN                NaN          NaN
#
#                ...              RXCUI_from_unii  INN_ID_from_unii  \
# 0              ...                          NaN               NaN
# 1              ...                          NaN               NaN
# 2              ...                          NaN               NaN
# 3              ...                          NaN               NaN
# 4              ...                          NaN               NaN
# 5              ...                          NaN               NaN
# 6              ...                          NaN               NaN
# 7              ...                          NaN               NaN
# 8              ...                      21232.0               NaN
# 9              ...                          NaN               NaN
# 10             ...                          NaN               NaN
# 11             ...                          NaN               NaN
# 12             ...                          NaN               NaN
# 13             ...                          NaN               NaN
# 14             ...                          NaN            1686.0
# 15             ...                          NaN               NaN
# 16             ...                          NaN               NaN
# 17             ...                          NaN               NaN
# 18             ...                          NaN               NaN
# 19             ...                          NaN               NaN
#
#        MF_from_unii           INCHIKEY_from_unii  \
# 0           C13H22O  GYUZHTWCNKINPY-WCQYABFASA-N
# 1   2Al.2Ca.3O.O4Si  WMWJKESBRPVNQB-UHFFFAOYSA-N
# 2    C19H24N2O4.ClH                          NaN
# 3              C3O2  GNEVIACKFGQMHB-UHFFFAOYSA-N
# 4            C18H20  ZOKCNEIWFQCSCM-UHFFFAOYSA-N
# 5         C12H3Br7O  NLBLNZDNOSSGPW-UHFFFAOYSA-N
# 6      3C18H35O2.Ce  BTVVNGIPFPKDHO-UHFFFAOYSA-K
# 7      C17H16ClN5O2  ZRJGMDIPCQOGNI-UHFFFAOYSA-N
# 8         C22H26NO3                          NaN
# 9          C15H16O5  RSIWXFIBHXYNFM-NSHDSACASA-N
# 10         C10H12O2  VHOMAPWVLKRQAZ-UHFFFAOYSA-N
# 11      C15H15N3O7S  OUSLHGWWWMRAIG-FBCAJUAOSA-N
# 12     C23H33N2O6PS  WFFOOKSVFDUPDH-FCHUYYIVSA-N
# 13     C19H29N5O6S2  KQHKTHFVDIBYJZ-UHFFFAOYSA-N
# 14       C39H53N3O9  WFTSRDISOMSAQC-ZNFOTRSXSA-N
# 15           C8H11N  OIALIKXMLIAOSN-UHFFFAOYSA-N
# 16         C15H30N2                          NaN
# 17          C13H18O                          NaN
# 18     C10H12ClN5O4  MHDPPLULTMGBSI-UUOKFMHZSA-N
# 19       C11H12Cl3N                          NaN
#
#                                      SMILES_from_unii   UNII_TYPE_from_unii  \
# 0                   C[C@H]1CC[C@@]2(O1)C(=CCCC2(C)C)C  INGREDIENT SUBSTANCE
# 1   [O-2].[O-2].[O-2].[O-][Si]([O-])([O-])[O-].[Al...  INGREDIENT SUBSTANCE
# 2             Cc1ccccc1OCC(CNCCOc2ccc(cc2)C(=O)N)O.Cl  INGREDIENT SUBSTANCE
# 3                                         C(=C=O)=C=O  INGREDIENT SUBSTANCE
# 4                       CC(C)(CC(=C)c1ccccc1)c2ccccc2  INGREDIENT SUBSTANCE
# 5       c1cc(c(c(c1)Br)Br)Oc2c(c(c(c(c2Br)Br)Br)Br)Br  INGREDIENT SUBSTANCE
# 6   CCCCCCCCCCCCCCCCCC(=O)[O-].CCCCCCCCCCCCCCCCCC(...  INGREDIENT SUBSTANCE
# 7         Cn1c(ccn1)C(=O)Nc2ccc(c(n2)N)c3cc(ccc3Cl)OC  INGREDIENT SUBSTANCE
# 8    C[N+]12CCC(CC1)C(C2)OC(=O)C(c3ccccc3)(c4ccccc4)O          IONIC MOIETY
# 9              COC1=CC(=O)O[C@H](C1)CCc2ccc3c(c2)OCO3  INGREDIENT SUBSTANCE
# 10                                  CCC(=O)OCc1ccccc1  INGREDIENT SUBSTANCE
# 11  CO/N=C(/c1ccco1)\C(=O)N[C@H]2[C@@H]3N(C2=O)C(=...  INGREDIENT SUBSTANCE
# 12  CC(C)[C@H](NS(=O)(=O)CCCc1ccccc1)P(=O)(C[C@@H]...  INGREDIENT SUBSTANCE
# 13      CN1CCC=C(C1)c2c(nsn2)OCCOCCOCCOCCOc3c(nsn3)OC  INGREDIENT SUBSTANCE
# 14  CCN(CC)CCn1c2cc(ccc2c3c1[C@H]4C[C@H]5[C@H](C[C...  INGREDIENT SUBSTANCE
# 15                                        CCCc1ccccn1  INGREDIENT SUBSTANCE
# 16                        CC1CC(CCC1N)CC2CCC(C(C2)C)N  INGREDIENT SUBSTANCE
# 17                            CC(C)c1cccc(c1)C(C)CC=O  INGREDIENT SUBSTANCE
